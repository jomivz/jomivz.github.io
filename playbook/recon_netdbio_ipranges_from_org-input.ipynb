# %%
# IMPORTS 
import csv
from networksdb import NetworksDB
import pandas as pd
import datetime

# %%
# OPTION 1 : import the key api named 'networksdb' from the keyring manager
# below the python cli (to execute once) create the api key : 
# >>> import keyring
# >>> import readline
# >>> keyring.set_password(service_name="networksdb",username="None",password="xxx")
# >>> readline.clear_history()

keyring.get_keyring()
netdbio_apikey = keyring.get_credential("networksdb", "None")
netdbio_api = NetworksDB(netdbio_apikey.password)

# %%
# OPTION 2 : import the key api named from the environment variable 
import os
#netdbio_apikey = os.environ['NETDBIO_API_KEY']
netdbio_apikey = input()
netdbio_api = NetworksDB(netdbio_apikey)

# %%
# ENTER THE ORGANIZATION NAME :  
org_name = input("Enter the organizarion name: ")
print("** Get IP ranges from networksdb.io for", org_name.upper())
# Out:
# ** Get IP ranges from networksdb.io for EDF

# %%
# RETRIEVE / SAVE THE IP RANGES TO FILE
org_data = ""

def save_ipranges_to_csv(org_name):
    
    org_data = netdbio_api.org_search(org_name)
    print(org_data)
    org_net_list = []
    for i in range(0,len(org_data.results)-1) :

        net_id = org_data.results[i].id
        ipranges = netdbio_api.org_networks(net_id)

        for ipr in ipranges.results:

            if ipr.cidr != "N/A":            
                ipr_sum = [ipr.netname, ipr.description, ipr.cidr]
                org_net_list.append(ipr_sum)

    pd.set_option('display.max_colwidth', None)            
    df = pd.DataFrame(org_net_list, columns=['net_name', 'desc', 'IP'])
    df.set_index('net_name', inplace=True)
    current_date = datetime.datetime.now()
    cdate = str(current_date.year) + f'{current_date.month:02d}' + f'{current_date.day:02d}'
    input_file = "~/NetDBio_IPranges_" + org_name + "_" + cdate + ".csv"
    df.to_csv(input_file)
    return input_file

org_name = org_name.replace(" ","-")
file = save_ipranges_to_csv(org_name)
print("** Results save to:", file)
# Out:
# {
#     "total": 102,
#     "page": 1,
#     "results": [
#         {
#             "organisation": "Edf Net05G",
#             "id": "edf-net05g",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 6,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-net05g",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Net",
#             "id": "edf-net",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-net",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Net05I",
#             "id": "edf-net05i",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-net05i",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Hosting and WEB Services Limited",
#             "id": "edf-hosting-and-web-services-ltd",
#             "countries": [
#                 "United Kingdom",
#                 "Spain",
#                 "India"
#             ],
#             "networks": {
#                 "ipv4": 14,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-hosting-and-web-services-ltd",
#             "asns": [
#                 "211271"
#             ]
#         },
#         {
#             "organisation": "EDF Trading North America, LLC",
#             "id": "edf-trading-north-america-llc",
#             "countries": [
#                 "United States"
#             ],
#             "networks": {
#                 "ipv4": 45,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-trading-north-america-llc",
#             "asns": [
#                 "15229"
#             ]
#         },
#         {
#             "organisation": "EDF Trading Ltd",
#             "id": "edf-trading-ltd",
#             "countries": [
#                 "United Kingdom",
#                 "United States",
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 11,
#                 "ipv6": 5
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-trading-ltd",
#             "asns": [
#                 "21464"
#             ]
#         },
#         {
#             "organisation": "EDF Energy (Asset Management) Ltd",
#             "id": "edf-energy-asset-management-ltd",
#             "countries": [
#                 "United Kingdom"
#             ],
#             "networks": {
#                 "ipv4": 45,
#                 "ipv6": 2
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-energy-asset-management-ltd",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Renewables, Inc",
#             "id": "edf-renewables-inc",
#             "countries": [
#                 "United States"
#             ],
#             "networks": {
#                 "ipv4": 3,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-renewables-inc",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Renouvelables S.A.",
#             "id": "edf-renouvelables-sa",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 20,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-renouvelables-sa",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Renewable Energy, Inc",
#             "id": "edf-renewable-energy-inc",
#             "countries": [
#                 "United States"
#             ],
#             "networks": {
#                 "ipv4": 20,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-renewable-energy-inc",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Polska S.A.",
#             "id": "edf-polska-sa",
#             "countries": [
#                 "Poland"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-polska-sa",
#             "asns": [
#                 "49149"
#             ]
#         },
#         {
#             "organisation": "Edf Energies Nouvelles",
#             "id": "edf-energies-nouvelles",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 72,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-energies-nouvelles",
#             "asns": []
#         },
#         {
#             "organisation": "EDF MAN Holdings",
#             "id": "edf-man-holdings",
#             "countries": [
#                 "United States"
#             ],
#             "networks": {
#                 "ipv4": 16,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-man-holdings",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Energy NNB",
#             "id": "edf-energy-nnb",
#             "countries": [
#                 "United Kingdom"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-energy-nnb",
#             "asns": []
#         },
#         {
#             "organisation": "Edf S.A.",
#             "id": "edf-sa",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 53,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-sa",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Renewables",
#             "id": "edf-renewables",
#             "countries": [
#                 "United Kingdom"
#             ],
#             "networks": {
#                 "ipv4": 14,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-renewables",
#             "asns": []
#         },
#         {
#             "organisation": "EDF",
#             "id": "edf",
#             "countries": [
#                 "United Kingdom",
#                 "Tanzania",
#                 "Japan"
#             ],
#             "networks": {
#                 "ipv4": 13,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Sei Corse",
#             "id": "edf-sei-corse",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 20,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-sei-corse",
#             "asns": []
#         },
#         {
#             "organisation": "Rte Edf Transport",
#             "id": "rte-edf-transport",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/rte-edf-transport",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Energy PLC",
#             "id": "edf-energy-plc",
#             "countries": [
#                 "United Kingdom"
#             ],
#             "networks": {
#                 "ipv4": 5,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-energy-plc",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Development, Inc",
#             "id": "edf-development-inc",
#             "countries": [
#                 "United States"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-development-inc",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Energy Renewables Ltd",
#             "id": "edf-energy-renewables-ltd",
#             "countries": [
#                 "United Kingdom",
#                 "Ireland"
#             ],
#             "networks": {
#                 "ipv4": 5,
#                 "ipv6": 3
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-energy-renewables-ltd",
#             "asns": []
#         },
#         {
#             "organisation": "EDF ITS Carat",
#             "id": "edf-its-carat",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 28,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-its-carat",
#             "asns": []
#         },
#         {
#             "organisation": "Developpement EDF EN Canada Inc",
#             "id": "developpement-edf-en-canada-inc",
#             "countries": [
#                 "Canada"
#             ],
#             "networks": {
#                 "ipv4": 3,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/developpement-edf-en-canada-inc",
#             "asns": []
#         },
#         {
#             "organisation": "Edf-Mann Trading",
#             "id": "edf-mann-trading",
#             "countries": [
#                 "United Kingdom"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-mann-trading",
#             "asns": []
#         },
#         {
#             "organisation": "Edf En France",
#             "id": "edf-en-france",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 10,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-en-france",
#             "asns": []
#         },
#         {
#             "organisation": "EDF US IDF LS TI GIT",
#             "id": "edf-us-idf-ls-ti-git",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 13,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-us-idf-ls-ti-git",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Inc",
#             "id": "edf-inc",
#             "countries": [
#                 "United States"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-inc",
#             "asns": []
#         },
#         {
#             "organisation": "Fondation D Entreprise Edf I",
#             "id": "fondation-d-entreprise-edf-i",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/fondation-d-entreprise-edf-i",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Seiso",
#             "id": "edf-seiso",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 12,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-seiso",
#             "asns": []
#         },
#         {
#             "organisation": "Edf En Services",
#             "id": "edf-en-services",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 8,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-en-services",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Production Elec Insulaire SAS",
#             "id": "edf-production-elec-insulaire-sas",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 3,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-production-elec-insulaire-sas",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Guyane",
#             "id": "edf-guyane",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-guyane",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Deutschland GmbH",
#             "id": "edf-deutschland-gmbh",
#             "countries": [
#                 "Germany"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-deutschland-gmbh",
#             "asns": []
#         },
#         {
#             "organisation": "EDF West Burton CCGT Power Station",
#             "id": "edf-west-burton-ccgt-power-station",
#             "countries": [
#                 "United Kingdom"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-west-burton-ccgt-power-station",
#             "asns": []
#         },
#         {
#             "organisation": "EDF U S I  ILE de France",
#             "id": "edf-u-s-i-ile-de-france",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-u-s-i-ile-de-france",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Energy Services, LLC",
#             "id": "edf-energy-services-llc",
#             "countries": [
#                 "United States"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-energy-services-llc",
#             "asns": []
#         },
#         {
#             "organisation": "EDF EN Service Italia",
#             "id": "edf-en-service-italia",
#             "countries": [
#                 "Italy"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-en-service-italia",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Trading (S) Pte Ltd",
#             "id": "edf-trading-s-pte-ltd",
#             "countries": [
#                 "Singapore"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-trading-s-pte-ltd",
#             "asns": []
#         },
#         {
#             "organisation": "EDF EN Deutschland GmbH",
#             "id": "edf-en-deutschland-gmbh",
#             "countries": [
#                 "Germany"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-en-deutschland-gmbh",
#             "asns": []
#         },
#         {
#             "organisation": "Fulg EDF",
#             "id": "fulg-edf",
#             "countries": [
#                 "United Kingdom"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/fulg-edf",
#             "asns": []
#         },
#         {
#             "organisation": "West Burton CCGT / EDF Energy",
#             "id": "west-burton-ccgt-edf-energy",
#             "countries": [
#                 "United Kingdom"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/west-burton-ccgt-edf-energy",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Asro",
#             "id": "edf-asro",
#             "countries": [
#                 "Romania"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-asro",
#             "asns": []
#         },
#         {
#             "organisation": "EDF MAN Liquid Products Italia SRL",
#             "id": "edf-man-liquid-products-italia-srl",
#             "countries": [
#                 "Italy"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-man-liquid-products-italia-srl",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Italia SPA",
#             "id": "edf-italia-spa",
#             "countries": [
#                 "Italy"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-italia-spa",
#             "asns": []
#         },
#         {
#             "organisation": "Frontier Interconnectoruk Edf",
#             "id": "frontier-interconnectoruk-edf",
#             "countries": [
#                 "United Kingdom"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/frontier-interconnectoruk-edf",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Daip Step ART Grand EST",
#             "id": "edf-daip-step-art-grand-est",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 5,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-daip-step-art-grand-est",
#             "asns": []
#         },
#         {
#             "organisation": "EDF GDF Distribution Toulouse",
#             "id": "edf-gdf-distribution-toulouse",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 3,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-gdf-distribution-toulouse",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Promotions Philippines Incorpora",
#             "id": "edf-promotions-philippines-incorpora",
#             "countries": [
#                 "Philippines"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-promotions-philippines-incorpora",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Pei",
#             "id": "edf-pei",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-pei",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Dpi Dpih Dtg",
#             "id": "edf-dpi-dpih-dtg",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-dpi-dpih-dtg",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Promotions Phils Inc",
#             "id": "edf-promotions-phils-inc",
#             "countries": [
#                 "Philippines"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-promotions-phils-inc",
#             "asns": []
#         },
#         {
#             "organisation": "EDF HQ Singapore Pte Ltd",
#             "id": "edf-hq-singapore-pte-ltd",
#             "countries": [
#                 "Singapore"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-hq-singapore-pte-ltd",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Cnpe Blayais Blaye",
#             "id": "edf-cnpe-blayais-blaye",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-cnpe-blayais-blaye",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Energia Italia SRL",
#             "id": "edf-energia-italia-srl",
#             "countries": [
#                 "Italy"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-energia-italia-srl",
#             "asns": []
#         },
#         {
#             "organisation": "Edf EN CANADA 333 BLOOR",
#             "id": "edf-en-canada-333-bloor",
#             "countries": [
#                 "Canada"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-en-canada-333-bloor",
#             "asns": []
#         },
#         {
#             "organisation": "EDF International S.A.",
#             "id": "edf-international-sa",
#             "countries": [
#                 "Italy"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-international-sa",
#             "asns": []
#         },
#         {
#             "organisation": "EDF & MAN",
#             "id": "edf-and-man",
#             "countries": [
#                 "Spain"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-and-man",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Production Elec",
#             "id": "edf-production-elec",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-production-elec",
#             "asns": []
#         },
#         {
#             "organisation": "Internet EDF Yaounde",
#             "id": "internet-edf-yaounde",
#             "countries": [
#                 "Cameroon"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/internet-edf-yaounde",
#             "asns": []
#         },
#         {
#             "organisation": "EDF ENR Solare SRL",
#             "id": "edf-enr-solare-srl",
#             "countries": [
#                 "Italy"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-enr-solare-srl",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Trading North Amer LLC",
#             "id": "edf-trading-north-amer-llc",
#             "countries": [
#                 "United States"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-trading-north-amer-llc",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Man Portugal Lda",
#             "id": "edf-man-portugal-lda",
#             "countries": [
#                 "Portugal"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-man-portugal-lda",
#             "asns": []
#         },
#         {
#             "organisation": "EDF MAN FRANCE Final Config O",
#             "id": "edf-man-france-final-config-o",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-man-france-final-config-o",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Energy Nuclear Generation Limited",
#             "id": "edf-energy-nuclear-generation-ltd",
#             "countries": [
#                 "United Kingdom"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-energy-nuclear-generation-ltd",
#             "asns": []
#         },
#         {
#             "organisation": "EDF EN Italia - Societa' PER Azioni",
#             "id": "edf-en-italia-societa-per-azioni",
#             "countries": [
#                 "Italy"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-en-italia-societa-per-azioni",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Belgium",
#             "id": "edf-belgium",
#             "countries": [
#                 "Belgium"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-belgium",
#             "asns": []
#         },
#         {
#             "organisation": "Ceo Internet Edf Negret- 2026739.co",
#             "id": "ceo-internet-edf-negret-2026739-co",
#             "countries": [
#                 "Colombia"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/ceo-internet-edf-negret-2026739-co",
#             "asns": []
#         },
#         {
#             "organisation": "EDF EN Portugal Unipessoal LDA",
#             "id": "edf-en-portugal-unipessoal-lda",
#             "countries": [
#                 "Portugal"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-en-portugal-unipessoal-lda",
#             "asns": []
#         },
#         {
#             "organisation": "EDF-EN-ITALIA-SPA Network",
#             "id": "edf-en-italia-spa-network",
#             "countries": [
#                 "Italy"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-en-italia-spa-network",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Man Terminals Denmark Aps",
#             "id": "edf-man-terminals-denmark-aps",
#             "countries": [
#                 "Denmark"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-man-terminals-denmark-aps",
#             "asns": []
#         },
#         {
#             "organisation": "EDF LAB Singapore Pte Ltd",
#             "id": "edf-lab-singapore-pte-ltd",
#             "countries": [
#                 "Singapore"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-lab-singapore-pte-ltd",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Dsp",
#             "id": "edf-dsp",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 4,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-dsp",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Renouvelables France",
#             "id": "edf-renouvelables-france",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 6,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-renouvelables-france",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Usine Hydro Electrique",
#             "id": "edf-usine-hydro-electrique",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 6,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-usine-hydro-electrique",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Gdf Distribution Paris Nord",
#             "id": "edf-gdf-distribution-paris-nord",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-gdf-distribution-paris-nord",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Holding BV",
#             "id": "edf-holding-bv",
#             "countries": [
#                 "Netherlands"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 1
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-holding-bv",
#             "asns": []
#         },
#         {
#             "organisation": "Publique edf Pack",
#             "id": "publique-edf-pack",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/publique-edf-pack",
#             "asns": []
#         },
#         {
#             "organisation": "Cssi Lyon Edf Lyon",
#             "id": "cssi-lyon-edf-lyon",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/cssi-lyon-edf-lyon",
#             "asns": []
#         },
#         {
#             "organisation": "Batchenga EDF Internet",
#             "id": "batchenga-edf-internet",
#             "countries": [
#                 "Cameroon"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/batchenga-edf-internet",
#             "asns": []
#         },
#         {
#             "organisation": "EDF EN Services Italia SRL in Breve EDF EN SI SRL",
#             "id": "edf-en-services-italia-s-r-l-in-breve-edf-en-si-srl",
#             "countries": [
#                 "Italy"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-en-services-italia-s-r-l-in-breve-edf-en-si-srl",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Us Idf",
#             "id": "edf-us-idf",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-us-idf",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Dppm",
#             "id": "edf-dppm",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-dppm",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Csp It Its No",
#             "id": "edf-csp-it-its-no",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-csp-it-its-no",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Nuclear Czechia, Odstepny Zavod",
#             "id": "edf-nuclear-czechia-odstepny-zavod",
#             "countries": [
#                 "Czech Republic"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-nuclear-czechia-odstepny-zavod",
#             "asns": []
#         },
#         {
#             "organisation": "Internet Public EDF",
#             "id": "internet-public-edf",
#             "countries": [
#                 "Cameroon"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/internet-public-edf",
#             "asns": []
#         },
#         {
#             "organisation": "EDF (COAL) Australia P/L",
#             "id": "edf-coal-australia-p-l",
#             "countries": [
#                 "Australia"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-coal-australia-p-l",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Commerce Departement Comptable",
#             "id": "edf-commerce-departement-comptable",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 2,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-commerce-departement-comptable",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Barrage des Brevieres",
#             "id": "edf-barrage-des-brevieres",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-barrage-des-brevieres",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Re France Strasbourg",
#             "id": "edf-re-france-strasbourg",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-re-france-strasbourg",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Dircom Regie Video",
#             "id": "edf-dircom-regie-video",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-dircom-regie-video",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Unitep Art Ge Direction",
#             "id": "edf-unitep-art-ge-direction",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-unitep-art-ge-direction",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Unitep Step",
#             "id": "edf-unitep-step",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-unitep-step",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Dcpp SUD Ouest",
#             "id": "edf-dcpp-sud-ouest",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-dcpp-sud-ouest",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Re Balma",
#             "id": "edf-re-balma",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-re-balma",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Direction Commerce Dcecl Ouest",
#             "id": "edf-direction-commerce-dcecl-ouest",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-direction-commerce-dcecl-ouest",
#             "asns": []
#         },
#         {
#             "organisation": "Rte Edf",
#             "id": "rte-edf",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/rte-edf",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Concession and Trading Services Inc",
#             "id": "edf-concession-and-trading-services-inc",
#             "countries": [
#                 "Philippines"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-concession-and-trading-services-inc",
#             "asns": []
#         },
#         {
#             "organisation": "EDF Lyon",
#             "id": "edf-lyon",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-lyon",
#             "asns": []
#         },
#         {
#             "organisation": "Edf Ile de la Reunion Production",
#             "id": "edf-ile-de-la-reunion-production",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-ile-de-la-reunion-production",
#             "asns": []
#         },
#         {
#             "organisation": "EDF GDF Service Lille Metropole",
#             "id": "edf-gdf-service-lille-metropole",
#             "countries": [
#                 "France"
#             ],
#             "networks": {
#                 "ipv4": 1,
#                 "ipv6": 0
#             },
#             "url": "https://networksdb.io/ip-addresses-of/edf-gdf-service-lille-metropole",
#             "asns": []
#         }
#     ]
# }
# ** Results save to: ~/NetDBio_IPranges_EDF_20220916.csv
